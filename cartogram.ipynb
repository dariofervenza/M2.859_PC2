# %%
import geoplot as gplt
import geoplot.crs as gcrs
import imageio
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numba
import cartopy.crs as ccrs

# %%
mapa = gpd.read_file("data/cb_2018_us_state_500k/cb_2018_us_state_500k.shp")
mapa.head()
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS  \
# 0       28  01779790  0400000US28    28     MS
# 1       37  01027616  0400000US37    37     NC
# 2       40  01102857  0400000US40    40     OK
# 3       51  01779803  0400000US51    51     VA
# 4       54  01779805  0400000US54    54     WV
# 5       22  01629543  0400000US22    22     LA
# 6       26  01779789  0400000US26    26     MI
# 7       25  00606926  0400000US25    25     MA
# 8       16  01779783  0400000US16    16     ID
# 9       12  00294478  0400000US12    12     FL
# 10      31  01779792  0400000US31    31     NE
# 11      53  01779804  0400000US53    53     WA
# 12      35  00897535  0400000US35    35     NM
# 13      72  01779808  0400000US72    72     PR
# 14      46  01785534  0400000US46    46     SD
# 15      48  01779801  0400000US48    48     TX
# 16      06  01779778  0400000US06    06     CA
# 17      01  01779775  0400000US01    01     AL
# 18      13  01705317  0400000US13    13     GA
# ...

# %%
df = pd.read_csv("data/median-household-income-by-state-2024.csv")
df.head()
# Out:
#         state  MedianHouseholdIncome2021
# 0     Alabama                    53913.0
# 1      Alaska                    77845.0
# 2     Arizona                    69056.0
# 3    Arkansas                    52528.0
# 4  California                    84907.0

# %%
mapa = mapa.merge(df, left_on="NAME", right_on="state", how="inner")
mapa.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS            NAME LSAD  \
# 0      28  01779790  0400000US28    28     MS     Mississippi   00
# 1      37  01027616  0400000US37    37     NC  North Carolina   00
# 2      40  01102857  0400000US40    40     OK        Oklahoma   00
# 3      51  01779803  0400000US51    51     VA        Virginia   00
# 4      54  01779805  0400000US54    54     WV   West Virginia   00
#
#           ALAND       AWATER  \
# 0  121533519481   3926919758
# 1  125923656064  13466071395
# 2  177662925723   3374587997
# 3  102257717110   8528531774
# 4   62266474513    489028543
#
#                                             geometry           state  \
# 0  MULTIPOLYGON (((-88.50297 30.21524, -88.49176 ...     Mississippi
# 1  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...  North Carolina
# 2  POLYGON ((-103.00256 36.52659, -103.00219 36.6...        Oklahoma
# 3  MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...        Virginia
# ...

# %%
geo_df = gpd.GeoDataFrame(mapa, geometry='geometry')
geo_df.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS            NAME LSAD  \
# 0      28  01779790  0400000US28    28     MS     Mississippi   00
# 1      37  01027616  0400000US37    37     NC  North Carolina   00
# 2      40  01102857  0400000US40    40     OK        Oklahoma   00
# 3      51  01779803  0400000US51    51     VA        Virginia   00
# 4      54  01779805  0400000US54    54     WV   West Virginia   00
#
#           ALAND       AWATER  \
# 0  121533519481   3926919758
# 1  125923656064  13466071395
# 2  177662925723   3374587997
# 3  102257717110   8528531774
# 4   62266474513    489028543
#
#                                             geometry           state  \
# 0  MULTIPOLYGON (((-88.50297 30.21524, -88.49176 ...     Mississippi
# 1  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...  North Carolina
# 2  POLYGON ((-103.00256 36.52659, -103.00219 36.6...        Oklahoma
# 3  MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...        Virginia
# ...

# %%
geo_df.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# ...

# %%
geo_df.iloc[0:].plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(15, 15), subplot_kw={'projection': gcrs.PlateCarree(central_longitude=-20)})
gplt.polyplot(geo_df, ax=ax)
gplt.choropleth(
    geo_df,
    hue="MedianHouseholdIncome2021",
    edgecolor="white",
    linewidth=1,
    cmap="Greens",
    legend=True,
    scheme="FisherJenks",
    ax=ax
)
ax.set_xlim(-180, -10)
ax.set_ylim(25, 74)
ax.set_title("Cartograma de income familiar en EEUU")
fig.savefig("images/mapa_eeuu.png")
